# %% [markdown]
# Notebook containing the preprocessing steps for the steel.csv dataset for A2.

# %%
#import steel dataset and store 

import pandas as pd

pd.set_option('display.width', 200)
df = pd.read_csv('steel.csv')

print("pandas dataframe:\n", df.head())

tf = df.to_numpy()
print("\nnumpy array:\n", tf[:5])

# %% [markdown]
# Separate Features (X) and targets (y) and store for use in models

# %%
X = tf[:, 0:9]                      # get features from dataset
print("\nFeatures (X):\n", X[:5])

y = tf[:, 9]                        # extract targets from dataset
print("\nTarget (y):\n", y[:5])

# %store X
# %store y
# Out:
# Features (X):
#  [[1.78500000e+02 2.75000000e+02 1.53000000e-01 9.70574759e-01
#   9.42000000e-01 8.87000000e-01 0.00000000e+00 1.92000000e+00
#   0.00000000e+00]
#  [1.78500000e+02 9.50000000e+02 1.53000000e-01 1.21272603e+00
#   9.42000000e-01 8.87000000e-01 0.00000000e+00 1.92000000e+00
#   0.00000000e+00]
#  [1.78500000e+02 3.75000000e+02 1.53000000e-01 1.62116483e+00
#   9.42000000e-01 8.87000000e-01 0.00000000e+00 1.92000000e+00
#   0.00000000e+00]
#  [1.78500000e+02 9.00000000e+02 1.53000000e-01 8.09988630e-01
#   9.42000000e-01 8.87000000e-01 0.00000000e+00 1.92000000e+00
#   0.00000000e+00]
#  [1.89525000e+02 9.00000000e+02 1.62400000e-01 1.03622926e+00
#   8.49000000e-01 9.38200000e-01 0.00000000e+00 2.03500000e+00
#   0.00000000e+00]]
#
# Target (y):
#  [ 25.10761328 140.0353335   42.21764969  95.01530861 113.2667725 ]
# Stored 'X' (ndarray)
# Stored 'y' (ndarray)
